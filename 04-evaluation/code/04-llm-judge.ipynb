# %%
from pydantic import BaseModel, Field
from typing import Literal

class AnswerEvaluation(BaseModel):
    reasoning: str = Field(
        description="Reasoning about the quality of the answer."
    )
    score: Literal["good", "bad"] = Field(
        description="'good' if the answer is correct and complete, 'bad' otherwise."
    )

# %%
aqa_judge_instructions = """
You are an expert evaluator. You will be given:
1. A question from a student
2. The original answer from the FAQ (ground truth)
3. An answer generated by an AI assistant

Your task is to decide if the AI answer is semantically equivalent to
the original answer.

Rules:
- The AI answer does NOT need to be word-for-word identical
- It should convey the same key information
- Extra detail is fine as long as the core answer is correct
- Mark 'bad' only if the AI answer is wrong or misses the key point

Be fair and focus on correctness, not style.
""".strip()

# %%
aqa_judge_prompt = """
Question:
{question}

Original Answer (ground truth):
{answer_orig}

AI Answer:
{answer_llm}
""".strip()

# %%
from dotenv import load_dotenv
from openai import OpenAI
from evaluation_utils import calc_price, calc_total_price, llm_structured_retry, map_progress

load_dotenv()
openai_client = OpenAI()

# %%
from dotenv import load_dotenv
from openai import OpenAI
from evaluation_utils import calc_price, calc_total_price, llm_structured_retry, map_progress

load_dotenv()
openai_client = OpenAI()

# %%
import pandas as pd

df_answers = pd.read_csv("../data/rag-answers-new.csv")
answers = df_answers.to_dict(orient="records")

# %%
rec = answers[0]
rec
# Out:
# {'question': 'Is it okay to join the course late if I just found it now?',
#  'answer_llm': 'Yes, you can still join the course late. If you want a certificate, though, you need to submit your project while submissions are still being accepted.',
#  'answer_orig': 'Yes, but if you want to receive a certificate, you need to submit your project while we’re still accepting submissions.',
#  'document': '74eb249bbf'}

# %%
prompt = aqa_judge_prompt.format(
    question=rec["question"],
    answer_orig=rec["answer_orig"],
    answer_llm=rec["answer_llm"]
)
print(prompt)
# Out:
# Question:
# Is it okay to join the course late if I just found it now?
#
# Original Answer (ground truth):
# Yes, but if you want to receive a certificate, you need to submit your project while we’re still accepting submissions.
#
# AI Answer:
# Yes, you can still join the course late. If you want a certificate, though, you need to submit your project while submissions are still being accepted.

# %%
eval_result, usage = llm_structured_retry(
    openai_client,
    aqa_judge_instructions,
    prompt,
    AnswerEvaluation,
)

eval_result
# Out:
# AnswerEvaluation(reasoning='The AI answer preserves the key point from the ground truth: late joining is allowed, but certificate eligibility depends on submitting the project while submissions are still open. This is semantically equivalent.', score='good')

# %%
calc_price(usage)
# Out:
# {'input_cost': 0.00022275000000000002,
#  'output_cost': 0.0002385,
#  'total_cost': 0.00046125}

# %%
def evaluate_aqa(question, answer_orig, answer_llm, model="gpt-5.4-mini"):
    prompt = aqa_judge_prompt.format(
        question=question,
        answer_orig=answer_orig,
        answer_llm=answer_llm
    )

    result, usage = llm_structured_retry(
        openai_client,
        aqa_judge_instructions,
        prompt,
        AnswerEvaluation,
        model=model,
    )

    return result, usage

# %%
eval_result, usage = evaluate_aqa(
    question=rec["question"],
    answer_orig=rec["answer_orig"],
    answer_llm=rec["answer_llm"]
)

eval_result
# Out:
# AnswerEvaluation(reasoning='The AI answer preserves the core meaning of the ground truth: late joining is allowed, but certificate eligibility depends on submitting the project while submissions are still open. This is semantically equivalent.', score='good')

# %%
def judge_record(rec):
    eval_result, usage = evaluate_aqa(
        question=rec["question"],
        answer_orig=rec["answer_orig"],
        answer_llm=rec["answer_llm"]
    )

    result = {
        "question": rec["question"],
        "document": rec["document"],
        "score": eval_result.score,
        "reasoning": eval_result.reasoning,
    }

    return result, usage

# %%
from concurrent.futures import ThreadPoolExecutor

with ThreadPoolExecutor(max_workers=6) as pool:
    results = map_progress(pool, answers, judge_record)
# Out:
#   0%|          | 0/395 [00:00<?, ?it/s]

# %%
results[10]
# Out:
# ({'question': 'How do I join the Office Hours or live workshop if I don’t have the Zoom link?',
#   'document': '489dd1c9d9',
#   'score': 'good',
#   'reasoning': 'The AI answer matches the ground truth: it says students do not need the Zoom link, participate via YouTube Live, find the video URL in Telegram/Slack announcements, can watch on the DataTalksClub YouTube channel, and submit questions via Slido. It preserves the key instruction that the Zoom link is for instructors/presenters/TAs only, though it omits the caution about not posting questions in chat. That omission does not change the core answer.'},
#  ResponseUsage(input_tokens=433, input_tokens_details=InputTokensDetails(cache_write_tokens=0, cached_tokens=0), output_tokens=110, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=543))

# %%
evaluations = []
usages = []

for evaluation, usage in results:
    evaluations.append(evaluation)
    usages.append(usage)

# %%
calc_total_price(usages)
# Out:
# 0.2540625

# %%
df_eval = pd.DataFrame(evaluations)

# %%
df_eval.head()
# Out:
#                                             question    document score  \
# 0  Is it okay to join the course late if I just f...  74eb249bbf  good
# 1  Can I still take this course even if I missed ...  74eb249bbf  good
# 2  If I join after the course has already started...  74eb249bbf  good
# 3  Do I need to submit my project before submissi...  74eb249bbf  good
# 4  I’m a bit late to the course—what do I need to...  74eb249bbf  good
#
#                                            reasoning
# 0  The AI answer preserves the key meaning of the...
# 1  The AI answer preserves the core meaning of th...
# 2  The AI answer preserves the core meaning of th...
# 3  The AI answer preserves the key meaning of the...
# 4  The AI answer includes the key requirement fro...

# %%
df_eval.score.value_counts()
# Out:
# score
# good    379
# bad      16
# Name: count, dtype: int64

# %%
df_eval.score.value_counts(normalize=True)
# Out:
# score
# good    0.959494
# bad     0.040506
# Name: proportion, dtype: float64

# %%
df_eval[df_eval["score"] == "bad"].head()
# Out:
#                                               question    document score  \
# 15   How do the free GPU hours work on these cloud ...  c6c2888275   bad
# 29   Is peer-review of the capstone project require...  69d122f12e   bad
# 38   How will I know when a module is actually read...  96286b4be4   bad
# 106  Do I need an OpenAI API key just to check how ...  fe8fed31e6   bad
# 124  What model or provider should I switch to if I...  6e1d8a7b29   bad
#
#                                              reasoning
# 15   The AI answer does not convey the substance of...
# 29   The AI answer states that peer-reviewing 3 cap...
# 38   The AI answer does not convey the ground truth...
# 106  The AI answer does not answer the question and...
# 124  The AI answer fails to provide any of the requ...

# %%
df_eval.to_csv("../data/rag-evaluations-new.csv", index=False)
